# %% [markdown]
# # CV Challenge Task

# %% [markdown]
#  ### Task 1: Preparing the data in the requested format

# %%
import os
import glob
import tensorflow as tf
import xml.etree.ElementTree as ET

# Function to parse XML annotations
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    width = int(root.find('size').find('width').text)
    height = int(root.find('size').find('height').text)
    filename = root.find('filename').text
    source_id = root.find('source').find('database').text
    
    # Extract bounding box coordinates and class labels
    bboxes = []
    class_labels = []
    for obj in root.findall('object'):
        xmin = float(obj.find('bndbox').find('xmin').text)
        ymin = float(obj.find('bndbox').find('ymin').text)
        xmax = float(obj.find('bndbox').find('xmax').text)
        ymax = float(obj.find('bndbox').find('ymax').text)
        bbox = [xmin, xmax, ymin, ymax]
        bboxes.append(bbox)
        
        class_text = obj.find('name').text
        class_labels.append(class_text.encode('utf-8'))  # Encode class label to bytes
    
    return width, height, filename.encode('utf-8'), source_id.encode('utf-8'), bboxes, class_labels

# Function to encode image to raw bytes
def encode_image(image_path):
    with tf.io.gfile.GFile(image_path, 'rb') as f:
        encoded_image = f.read()
    return encoded_image

# Function to create TFRecord file
def create_tfrecord(images_dir, annotations_dir, output_file):
    writer = tf.io.TFRecordWriter(output_file)
    
    annotations = glob.glob(os.path.join(annotations_dir, '*.xml'))
    for annotation in annotations:
        image_filename = os.path.splitext(os.path.basename(annotation))[0] + '.jpg'
        word_before_underscore = image_filename.split('_')[0]
        image_path = os.path.join(images_dir,word_before_underscore, image_filename)
        print("-----------------------------")
        print(image_filename)
        print(image_path)
        if not os.path.exists(image_path):
            print(f"Image file '{image_path}' not found. Skipping...")
            continue
        
        width, height, filename, source_id, bboxes, class_labels = parse_xml(annotation)
        encoded_image = encode_image(image_path)
        
        if not encoded_image:
            print(f"Failed to encode image '{image_path}'. Skipping...")
            continue
        
        feature = {
            "image/width": tf.train.Feature(int64_list=tf.train.Int64List(value=[width])),
            "image/height": tf.train.Feature(int64_list=tf.train.Int64List(value=[height])),
            'image/filename': tf.train.Feature(bytes_list=tf.train.BytesList(value=[filename])),
            'image/source_id': tf.train.Feature(bytes_list=tf.train.BytesList(value=[source_id])),
            'image/encodedrawdata': tf.train.Feature(bytes_list=tf.train.BytesList(value=[encoded_image])),
            'image/format': tf.train.Feature(bytes_list=tf.train.BytesList(value=['jpeg'.encode('utf-8')])),
            'image/object/bbox/xmin': tf.train.Feature(float_list=tf.train.FloatList(value=[bbox[0] for bbox in bboxes])),
            'image/object/bbox/xmax': tf.train.Feature(float_list=tf.train.FloatList(value=[bbox[1] for bbox in bboxes])),
            'image/object/bbox/ymin': tf.train.Feature(float_list=tf.train.FloatList(value=[bbox[2] for bbox in bboxes])),
            'image/object/bbox/ymax': tf.train.Feature(float_list=tf.train.FloatList(value=[bbox[3] for bbox in bboxes])),
            'image/object/class/text': tf.train.Feature(bytes_list=tf.train.BytesList(value=class_labels)),
            'image/object/class/label': tf.train.Feature(int64_list=tf.train.Int64List(value=[0])),  
            'image/object/class/single': tf.train.Feature(int64_list=tf.train.Int64List(value=[1])),  
            'image/object/difficult': tf.train.Feature(int64_list=tf.train.Int64List(value=[0])),  
            'image/object/truncated': tf.train.Feature(int64_list=tf.train.Int64List(value=[0])), 
            'image/object/view': tf.train.Feature(bytes_list=tf.train.BytesList(value=[])),  
        }
        
        example = tf.train.Example(features=tf.train.Features(feature=feature))
        writer.write(example.SerializeToString())
    
    writer.close()


# Main function to create TFRecord files for train and validation sets
def main():
    train_images_dir = 'D:/Downloads/NEU-DET/train/images/'
    train_annotations_dir = 'D:/Downloads/NEU-DET/train/annotations/'
    train_output_file = 'D:/Downloads/NEU-DET/train/output.tfrecord'
    create_tfrecord(train_images_dir, train_annotations_dir, train_output_file)
    
    val_images_dir = 'D:/Downloads/NEU-DET/validation/images/'
    val_annotations_dir = 'D:/Downloads/NEU-DET/validation/annotations/'
    val_output_file = 'D:/Downloads/NEU-DET/validation/output.tfrecord'
    create_tfrecord(val_images_dir, val_annotations_dir, val_output_file)

if __name__ == "__main__":
    main()
# Out:
# -----------------------------
# crazing_1.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_1.jpg
# -----------------------------
# crazing_10.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_10.jpg
# -----------------------------
# crazing_100.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_100.jpg
# -----------------------------
# crazing_101.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_101.jpg
# -----------------------------
# crazing_102.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_102.jpg
# -----------------------------
# crazing_103.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_103.jpg
# -----------------------------
# crazing_104.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_104.jpg
# -----------------------------
# crazing_105.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_105.jpg
# -----------------------------
# crazing_106.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_106.jpg
# -----------------------------
# crazing_107.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_107.jpg
# -----------------------------
# crazing_108.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_108.jpg
# -----------------------------
# crazing_109.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_109.jpg
# -----------------------------
# crazing_11.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_11.jpg
# -----------------------------
# crazing_110.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_110.jpg
# -----------------------------
# crazing_111.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_111.jpg
# -----------------------------
# crazing_112.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_112.jpg
# -----------------------------
# crazing_113.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_113.jpg
# -----------------------------
# crazing_114.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_114.jpg
# -----------------------------
# crazing_115.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_115.jpg
# -----------------------------
# crazing_116.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_116.jpg
# -----------------------------
# crazing_117.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_117.jpg
# -----------------------------
# crazing_118.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_118.jpg
# -----------------------------
# crazing_119.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_119.jpg
# -----------------------------
# crazing_12.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_12.jpg
# -----------------------------
# crazing_120.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_120.jpg
# -----------------------------
# crazing_121.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_121.jpg
# -----------------------------
# crazing_122.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_122.jpg
# -----------------------------
# crazing_123.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_123.jpg
# -----------------------------
# crazing_124.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_124.jpg
# -----------------------------
# crazing_125.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_125.jpg
# -----------------------------
# crazing_126.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_126.jpg
# -----------------------------
# crazing_127.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_127.jpg
# -----------------------------
# crazing_128.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_128.jpg
# -----------------------------
# crazing_129.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_129.jpg
# -----------------------------
# crazing_13.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_13.jpg
# -----------------------------
# crazing_130.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_130.jpg
# -----------------------------
# crazing_131.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_131.jpg
# -----------------------------
# crazing_132.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_132.jpg
# -----------------------------
# crazing_133.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_133.jpg
# -----------------------------
# crazing_134.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_134.jpg
# -----------------------------
# crazing_135.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_135.jpg
# -----------------------------
# crazing_136.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_136.jpg
# -----------------------------
# crazing_137.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_137.jpg
# -----------------------------
# crazing_138.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_138.jpg
# -----------------------------
# crazing_139.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_139.jpg
# -----------------------------
# crazing_14.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_14.jpg
# -----------------------------
# crazing_140.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_140.jpg
# -----------------------------
# crazing_141.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_141.jpg
# -----------------------------
# crazing_142.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_142.jpg
# -----------------------------
# crazing_143.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_143.jpg
# -----------------------------
# crazing_144.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_144.jpg
# -----------------------------
# crazing_145.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_145.jpg
# -----------------------------
# crazing_146.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_146.jpg
# -----------------------------
# crazing_147.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_147.jpg
# -----------------------------
# crazing_148.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_148.jpg
# -----------------------------
# crazing_149.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_149.jpg
# -----------------------------
# crazing_15.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_15.jpg
# -----------------------------
# crazing_150.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_150.jpg
# -----------------------------
# crazing_151.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_151.jpg
# -----------------------------
# crazing_152.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_152.jpg
# -----------------------------
# crazing_153.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_153.jpg
# -----------------------------
# crazing_154.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_154.jpg
# -----------------------------
# crazing_155.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_155.jpg
# -----------------------------
# crazing_156.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_156.jpg
# -----------------------------
# crazing_157.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_157.jpg
# -----------------------------
# crazing_158.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_158.jpg
# -----------------------------
# crazing_159.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_159.jpg
# -----------------------------
# crazing_16.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_16.jpg
# -----------------------------
# crazing_160.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_160.jpg
# -----------------------------
# crazing_161.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_161.jpg
# -----------------------------
# crazing_162.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_162.jpg
# -----------------------------
# crazing_163.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_163.jpg
# -----------------------------
# crazing_164.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_164.jpg
# -----------------------------
# crazing_165.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_165.jpg
# -----------------------------
# crazing_166.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_166.jpg
# -----------------------------
# crazing_167.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_167.jpg
# -----------------------------
# crazing_168.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_168.jpg
# -----------------------------
# crazing_169.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_169.jpg
# -----------------------------
# crazing_17.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_17.jpg
# -----------------------------
# crazing_170.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_170.jpg
# -----------------------------
# crazing_171.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_171.jpg
# -----------------------------
# crazing_172.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_172.jpg
# -----------------------------
# crazing_173.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_173.jpg
# -----------------------------
# crazing_174.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_174.jpg
# -----------------------------
# crazing_175.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_175.jpg
# -----------------------------
# crazing_176.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_176.jpg
# -----------------------------
# crazing_177.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_177.jpg
# -----------------------------
# crazing_178.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_178.jpg
# -----------------------------
# crazing_179.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_179.jpg
# -----------------------------
# crazing_18.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_18.jpg
# -----------------------------
# crazing_180.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_180.jpg
# -----------------------------
# crazing_181.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_181.jpg
# -----------------------------
# crazing_182.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_182.jpg
# -----------------------------
# crazing_183.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_183.jpg
# -----------------------------
# crazing_184.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_184.jpg
# -----------------------------
# crazing_185.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_185.jpg
# -----------------------------
# crazing_186.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_186.jpg
# -----------------------------
# crazing_187.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_187.jpg
# -----------------------------
# crazing_188.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_188.jpg
# -----------------------------
# crazing_189.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_189.jpg
# -----------------------------
# crazing_19.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_19.jpg
# -----------------------------
# crazing_190.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_190.jpg
# -----------------------------
# crazing_191.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_191.jpg
# -----------------------------
# crazing_192.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_192.jpg
# -----------------------------
# crazing_193.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_193.jpg
# -----------------------------
# crazing_194.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_194.jpg
# -----------------------------
# crazing_195.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_195.jpg
# -----------------------------
# crazing_196.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_196.jpg
# -----------------------------
# crazing_197.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_197.jpg
# -----------------------------
# crazing_198.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_198.jpg
# -----------------------------
# crazing_199.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_199.jpg
# -----------------------------
# crazing_2.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_2.jpg
# -----------------------------
# crazing_20.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_20.jpg
# -----------------------------
# crazing_200.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_200.jpg
# -----------------------------
# crazing_201.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_201.jpg
# -----------------------------
# crazing_202.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_202.jpg
# -----------------------------
# crazing_203.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_203.jpg
# -----------------------------
# crazing_204.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_204.jpg
# -----------------------------
# crazing_205.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_205.jpg
# -----------------------------
# crazing_206.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_206.jpg
# -----------------------------
# crazing_207.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_207.jpg
# -----------------------------
# crazing_208.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_208.jpg
# -----------------------------
# crazing_209.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_209.jpg
# -----------------------------
# crazing_21.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_21.jpg
# -----------------------------
# crazing_210.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_210.jpg
# -----------------------------
# crazing_211.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_211.jpg
# -----------------------------
# crazing_212.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_212.jpg
# -----------------------------
# crazing_213.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_213.jpg
# -----------------------------
# crazing_214.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_214.jpg
# -----------------------------
# crazing_215.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_215.jpg
# -----------------------------
# crazing_216.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_216.jpg
# -----------------------------
# crazing_217.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_217.jpg
# -----------------------------
# crazing_218.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_218.jpg
# -----------------------------
# crazing_219.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_219.jpg
# -----------------------------
# crazing_22.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_22.jpg
# -----------------------------
# crazing_220.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_220.jpg
# -----------------------------
# crazing_221.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_221.jpg
# -----------------------------
# crazing_222.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_222.jpg
# -----------------------------
# crazing_223.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_223.jpg
# -----------------------------
# crazing_224.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_224.jpg
# -----------------------------
# crazing_225.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_225.jpg
# -----------------------------
# crazing_226.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_226.jpg
# -----------------------------
# crazing_227.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_227.jpg
# -----------------------------
# crazing_228.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_228.jpg
# -----------------------------
# crazing_229.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_229.jpg
# -----------------------------
# crazing_23.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_23.jpg
# -----------------------------
# crazing_230.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_230.jpg
# -----------------------------
# crazing_231.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_231.jpg
# -----------------------------
# crazing_232.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_232.jpg
# -----------------------------
# crazing_233.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_233.jpg
# -----------------------------
# crazing_234.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_234.jpg
# -----------------------------
# crazing_235.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_235.jpg
# -----------------------------
# crazing_236.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_236.jpg
# -----------------------------
# crazing_237.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_237.jpg
# -----------------------------
# crazing_238.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_238.jpg
# -----------------------------
# crazing_239.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_239.jpg
# -----------------------------
# crazing_24.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_24.jpg
# -----------------------------
# crazing_240.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_240.jpg
# -----------------------------
# crazing_25.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_25.jpg
# -----------------------------
# crazing_26.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_26.jpg
# -----------------------------
# crazing_27.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_27.jpg
# -----------------------------
# crazing_28.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_28.jpg
# -----------------------------
# crazing_29.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_29.jpg
# -----------------------------
# crazing_3.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_3.jpg
# -----------------------------
# crazing_30.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_30.jpg
# -----------------------------
# crazing_31.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_31.jpg
# -----------------------------
# crazing_32.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_32.jpg
# -----------------------------
# crazing_33.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_33.jpg
# -----------------------------
# crazing_34.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_34.jpg
# -----------------------------
# crazing_35.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_35.jpg
# -----------------------------
# crazing_36.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_36.jpg
# -----------------------------
# crazing_37.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_37.jpg
# -----------------------------
# crazing_38.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_38.jpg
# -----------------------------
# crazing_39.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_39.jpg
# -----------------------------
# crazing_4.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_4.jpg
# -----------------------------
# crazing_40.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_40.jpg
# -----------------------------
# crazing_41.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_41.jpg
# -----------------------------
# crazing_42.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_42.jpg
# -----------------------------
# crazing_43.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_43.jpg
# -----------------------------
# crazing_44.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_44.jpg
# -----------------------------
# crazing_45.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_45.jpg
# -----------------------------
# crazing_46.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_46.jpg
# -----------------------------
# crazing_47.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_47.jpg
# -----------------------------
# crazing_48.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_48.jpg
# -----------------------------
# crazing_49.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_49.jpg
# -----------------------------
# crazing_5.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_5.jpg
# -----------------------------
# crazing_50.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_50.jpg
# -----------------------------
# crazing_51.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_51.jpg
# -----------------------------
# crazing_52.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_52.jpg
# -----------------------------
# crazing_53.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_53.jpg
# -----------------------------
# crazing_54.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_54.jpg
# -----------------------------
# crazing_55.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_55.jpg
# -----------------------------
# crazing_56.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_56.jpg
# -----------------------------
# crazing_57.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_57.jpg
# -----------------------------
# crazing_58.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_58.jpg
# -----------------------------
# crazing_59.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_59.jpg
# -----------------------------
# crazing_6.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_6.jpg
# -----------------------------
# crazing_60.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_60.jpg
# -----------------------------
# crazing_61.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_61.jpg
# -----------------------------
# crazing_62.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_62.jpg
# -----------------------------
# crazing_63.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_63.jpg
# -----------------------------
# crazing_64.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_64.jpg
# -----------------------------
# crazing_65.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_65.jpg
# -----------------------------
# crazing_66.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_66.jpg
# -----------------------------
# crazing_67.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_67.jpg
# -----------------------------
# crazing_68.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_68.jpg
# -----------------------------
# crazing_69.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_69.jpg
# -----------------------------
# crazing_7.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_7.jpg
# -----------------------------
# crazing_70.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_70.jpg
# -----------------------------
# crazing_71.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_71.jpg
# -----------------------------
# crazing_72.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_72.jpg
# -----------------------------
# crazing_73.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_73.jpg
# -----------------------------
# crazing_74.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_74.jpg
# -----------------------------
# crazing_75.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_75.jpg
# -----------------------------
# crazing_76.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_76.jpg
# -----------------------------
# crazing_77.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_77.jpg
# -----------------------------
# crazing_78.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_78.jpg
# -----------------------------
# crazing_79.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_79.jpg
# -----------------------------
# crazing_8.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_8.jpg
# -----------------------------
# crazing_80.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_80.jpg
# -----------------------------
# crazing_81.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_81.jpg
# -----------------------------
# crazing_82.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_82.jpg
# -----------------------------
# crazing_83.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_83.jpg
# -----------------------------
# crazing_84.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_84.jpg
# -----------------------------
# crazing_85.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_85.jpg
# -----------------------------
# crazing_86.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_86.jpg
# -----------------------------
# crazing_87.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_87.jpg
# -----------------------------
# crazing_88.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_88.jpg
# -----------------------------
# crazing_89.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_89.jpg
# -----------------------------
# crazing_9.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_9.jpg
# -----------------------------
# crazing_90.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_90.jpg
# -----------------------------
# crazing_91.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_91.jpg
# -----------------------------
# crazing_92.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_92.jpg
# -----------------------------
# crazing_93.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_93.jpg
# -----------------------------
# crazing_94.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_94.jpg
# -----------------------------
# crazing_95.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_95.jpg
# -----------------------------
# crazing_96.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_96.jpg
# -----------------------------
# crazing_97.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_97.jpg
# -----------------------------
# crazing_98.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_98.jpg
# -----------------------------
# crazing_99.jpg
# D:/Downloads/NEU-DET/train/images/crazing\crazing_99.jpg
# -----------------------------
# inclusion_1.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_1.jpg
# -----------------------------
# inclusion_10.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_10.jpg
# -----------------------------
# inclusion_100.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_100.jpg
# -----------------------------
# inclusion_101.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_101.jpg
# -----------------------------
# inclusion_102.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_102.jpg
# -----------------------------
# inclusion_103.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_103.jpg
# -----------------------------
# inclusion_104.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_104.jpg
# -----------------------------
# inclusion_105.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_105.jpg
# -----------------------------
# inclusion_106.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_106.jpg
# -----------------------------
# inclusion_107.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_107.jpg
# -----------------------------
# inclusion_108.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_108.jpg
# -----------------------------
# inclusion_109.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_109.jpg
# -----------------------------
# inclusion_11.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_11.jpg
# -----------------------------
# inclusion_110.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_110.jpg
# -----------------------------
# inclusion_111.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_111.jpg
# -----------------------------
# inclusion_112.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_112.jpg
# -----------------------------
# inclusion_113.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_113.jpg
# -----------------------------
# inclusion_114.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_114.jpg
# -----------------------------
# inclusion_115.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_115.jpg
# -----------------------------
# inclusion_116.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_116.jpg
# -----------------------------
# inclusion_117.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_117.jpg
# -----------------------------
# inclusion_118.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_118.jpg
# -----------------------------
# inclusion_119.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_119.jpg
# -----------------------------
# inclusion_12.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_12.jpg
# -----------------------------
# inclusion_120.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_120.jpg
# -----------------------------
# inclusion_121.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_121.jpg
# -----------------------------
# inclusion_122.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_122.jpg
# -----------------------------
# inclusion_123.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_123.jpg
# -----------------------------
# inclusion_124.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_124.jpg
# -----------------------------
# inclusion_125.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_125.jpg
# -----------------------------
# inclusion_126.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_126.jpg
# -----------------------------
# inclusion_127.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_127.jpg
# -----------------------------
# inclusion_128.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_128.jpg
# -----------------------------
# inclusion_129.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_129.jpg
# -----------------------------
# inclusion_13.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_13.jpg
# -----------------------------
# inclusion_130.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_130.jpg
# -----------------------------
# inclusion_131.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_131.jpg
# -----------------------------
# inclusion_132.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_132.jpg
# -----------------------------
# inclusion_133.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_133.jpg
# -----------------------------
# inclusion_134.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_134.jpg
# -----------------------------
# inclusion_135.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_135.jpg
# -----------------------------
# inclusion_136.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_136.jpg
# -----------------------------
# inclusion_137.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_137.jpg
# -----------------------------
# inclusion_138.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_138.jpg
# -----------------------------
# inclusion_139.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_139.jpg
# -----------------------------
# inclusion_14.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_14.jpg
# -----------------------------
# inclusion_140.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_140.jpg
# -----------------------------
# inclusion_141.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_141.jpg
# -----------------------------
# inclusion_142.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_142.jpg
# -----------------------------
# inclusion_143.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_143.jpg
# -----------------------------
# inclusion_144.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_144.jpg
# -----------------------------
# inclusion_145.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_145.jpg
# -----------------------------
# inclusion_146.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_146.jpg
# -----------------------------
# inclusion_147.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_147.jpg
# -----------------------------
# inclusion_148.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_148.jpg
# -----------------------------
# inclusion_149.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_149.jpg
# -----------------------------
# inclusion_15.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_15.jpg
# -----------------------------
# inclusion_150.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_150.jpg
# -----------------------------
# inclusion_151.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_151.jpg
# -----------------------------
# inclusion_152.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_152.jpg
# -----------------------------
# inclusion_153.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_153.jpg
# -----------------------------
# inclusion_154.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_154.jpg
# -----------------------------
# inclusion_155.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_155.jpg
# -----------------------------
# inclusion_156.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_156.jpg
# -----------------------------
# inclusion_157.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_157.jpg
# -----------------------------
# inclusion_158.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_158.jpg
# -----------------------------
# inclusion_159.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_159.jpg
# -----------------------------
# inclusion_16.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_16.jpg
# -----------------------------
# inclusion_160.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_160.jpg
# -----------------------------
# inclusion_161.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_161.jpg
# -----------------------------
# inclusion_162.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_162.jpg
# -----------------------------
# inclusion_163.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_163.jpg
# -----------------------------
# inclusion_164.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_164.jpg
# -----------------------------
# inclusion_165.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_165.jpg
# -----------------------------
# inclusion_166.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_166.jpg
# -----------------------------
# inclusion_167.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_167.jpg
# -----------------------------
# inclusion_168.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_168.jpg
# -----------------------------
# inclusion_169.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_169.jpg
# -----------------------------
# inclusion_17.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_17.jpg
# -----------------------------
# inclusion_170.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_170.jpg
# -----------------------------
# inclusion_171.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_171.jpg
# -----------------------------
# inclusion_172.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_172.jpg
# -----------------------------
# inclusion_173.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_173.jpg
# -----------------------------
# inclusion_174.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_174.jpg
# -----------------------------
# inclusion_175.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_175.jpg
# -----------------------------
# inclusion_176.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_176.jpg
# -----------------------------
# inclusion_177.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_177.jpg
# -----------------------------
# inclusion_178.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_178.jpg
# -----------------------------
# inclusion_179.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_179.jpg
# -----------------------------
# inclusion_18.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_18.jpg
# -----------------------------
# inclusion_180.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_180.jpg
# -----------------------------
# inclusion_181.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_181.jpg
# -----------------------------
# inclusion_182.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_182.jpg
# -----------------------------
# inclusion_183.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_183.jpg
# -----------------------------
# inclusion_184.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_184.jpg
# -----------------------------
# inclusion_185.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_185.jpg
# -----------------------------
# inclusion_186.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_186.jpg
# -----------------------------
# inclusion_187.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_187.jpg
# -----------------------------
# inclusion_188.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_188.jpg
# -----------------------------
# inclusion_189.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_189.jpg
# -----------------------------
# inclusion_19.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_19.jpg
# -----------------------------
# inclusion_190.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_190.jpg
# -----------------------------
# inclusion_191.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_191.jpg
# -----------------------------
# inclusion_192.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_192.jpg
# -----------------------------
# inclusion_193.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_193.jpg
# -----------------------------
# inclusion_194.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_194.jpg
# -----------------------------
# inclusion_195.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_195.jpg
# -----------------------------
# inclusion_196.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_196.jpg
# -----------------------------
# inclusion_197.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_197.jpg
# -----------------------------
# inclusion_198.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_198.jpg
# -----------------------------
# inclusion_199.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_199.jpg
# -----------------------------
# inclusion_2.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_2.jpg
# -----------------------------
# inclusion_20.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_20.jpg
# -----------------------------
# inclusion_200.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_200.jpg
# -----------------------------
# inclusion_201.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_201.jpg
# -----------------------------
# inclusion_202.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_202.jpg
# -----------------------------
# inclusion_203.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_203.jpg
# -----------------------------
# inclusion_204.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_204.jpg
# -----------------------------
# inclusion_205.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_205.jpg
# -----------------------------
# inclusion_206.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_206.jpg
# -----------------------------
# inclusion_207.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_207.jpg
# -----------------------------
# inclusion_208.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_208.jpg
# -----------------------------
# inclusion_209.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_209.jpg
# -----------------------------
# inclusion_21.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_21.jpg
# -----------------------------
# inclusion_210.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_210.jpg
# -----------------------------
# inclusion_211.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_211.jpg
# -----------------------------
# inclusion_212.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_212.jpg
# -----------------------------
# inclusion_213.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_213.jpg
# -----------------------------
# inclusion_214.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_214.jpg
# -----------------------------
# inclusion_215.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_215.jpg
# -----------------------------
# inclusion_216.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_216.jpg
# -----------------------------
# inclusion_217.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_217.jpg
# -----------------------------
# inclusion_218.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_218.jpg
# -----------------------------
# inclusion_219.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_219.jpg
# -----------------------------
# inclusion_22.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_22.jpg
# -----------------------------
# inclusion_220.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_220.jpg
# -----------------------------
# inclusion_221.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_221.jpg
# -----------------------------
# inclusion_222.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_222.jpg
# -----------------------------
# inclusion_223.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_223.jpg
# -----------------------------
# inclusion_224.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_224.jpg
# -----------------------------
# inclusion_225.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_225.jpg
# -----------------------------
# inclusion_226.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_226.jpg
# -----------------------------
# inclusion_227.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_227.jpg
# -----------------------------
# inclusion_228.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_228.jpg
# -----------------------------
# inclusion_229.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_229.jpg
# -----------------------------
# inclusion_23.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_23.jpg
# -----------------------------
# inclusion_230.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_230.jpg
# -----------------------------
# inclusion_231.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_231.jpg
# -----------------------------
# inclusion_232.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_232.jpg
# -----------------------------
# inclusion_233.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_233.jpg
# -----------------------------
# inclusion_234.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_234.jpg
# -----------------------------
# inclusion_235.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_235.jpg
# -----------------------------
# inclusion_236.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_236.jpg
# -----------------------------
# inclusion_237.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_237.jpg
# -----------------------------
# inclusion_238.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_238.jpg
# -----------------------------
# inclusion_239.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_239.jpg
# -----------------------------
# inclusion_24.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_24.jpg
# -----------------------------
# inclusion_240.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_240.jpg
# -----------------------------
# inclusion_25.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_25.jpg
# -----------------------------
# inclusion_26.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_26.jpg
# -----------------------------
# inclusion_27.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_27.jpg
# -----------------------------
# inclusion_28.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_28.jpg
# -----------------------------
# inclusion_29.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_29.jpg
# -----------------------------
# inclusion_3.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_3.jpg
# -----------------------------
# inclusion_30.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_30.jpg
# -----------------------------
# inclusion_31.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_31.jpg
# -----------------------------
# inclusion_32.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_32.jpg
# -----------------------------
# inclusion_33.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_33.jpg
# -----------------------------
# inclusion_34.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_34.jpg
# -----------------------------
# inclusion_35.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_35.jpg
# -----------------------------
# inclusion_36.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_36.jpg
# -----------------------------
# inclusion_37.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_37.jpg
# -----------------------------
# inclusion_38.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_38.jpg
# -----------------------------
# inclusion_39.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_39.jpg
# -----------------------------
# inclusion_4.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_4.jpg
# -----------------------------
# inclusion_40.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_40.jpg
# -----------------------------
# inclusion_41.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_41.jpg
# -----------------------------
# inclusion_42.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_42.jpg
# -----------------------------
# inclusion_43.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_43.jpg
# -----------------------------
# inclusion_44.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_44.jpg
# -----------------------------
# inclusion_45.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_45.jpg
# -----------------------------
# inclusion_46.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_46.jpg
# -----------------------------
# inclusion_47.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_47.jpg
# -----------------------------
# inclusion_48.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_48.jpg
# -----------------------------
# inclusion_49.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_49.jpg
# -----------------------------
# inclusion_5.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_5.jpg
# -----------------------------
# inclusion_50.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_50.jpg
# -----------------------------
# inclusion_51.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_51.jpg
# -----------------------------
# inclusion_52.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_52.jpg
# -----------------------------
# inclusion_53.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_53.jpg
# -----------------------------
# inclusion_54.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_54.jpg
# -----------------------------
# inclusion_55.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_55.jpg
# -----------------------------
# inclusion_56.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_56.jpg
# -----------------------------
# inclusion_57.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_57.jpg
# -----------------------------
# inclusion_58.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_58.jpg
# -----------------------------
# inclusion_59.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_59.jpg
# -----------------------------
# inclusion_6.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_6.jpg
# -----------------------------
# inclusion_60.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_60.jpg
# -----------------------------
# inclusion_61.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_61.jpg
# -----------------------------
# inclusion_62.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_62.jpg
# -----------------------------
# inclusion_63.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_63.jpg
# -----------------------------
# inclusion_64.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_64.jpg
# -----------------------------
# inclusion_65.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_65.jpg
# -----------------------------
# inclusion_66.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_66.jpg
# -----------------------------
# inclusion_67.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_67.jpg
# -----------------------------
# inclusion_68.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_68.jpg
# -----------------------------
# inclusion_69.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_69.jpg
# -----------------------------
# inclusion_7.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_7.jpg
# -----------------------------
# inclusion_70.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_70.jpg
# -----------------------------
# inclusion_71.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_71.jpg
# -----------------------------
# inclusion_72.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_72.jpg
# -----------------------------
# inclusion_73.jpg
# D:/Downloads/NEU-DET/train/images/inclusion\inclusion_73.jpg
# -----------------------------
# inclusion_74.jpg
# ...
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_262.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_263.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_263.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_263.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_264.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_264.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_264.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_265.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_265.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_265.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_266.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_266.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_266.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_267.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_267.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_267.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_268.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_268.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_268.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_269.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_269.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_269.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_270.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_270.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_270.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_271.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_271.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_271.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_272.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_272.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_272.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_273.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_273.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_273.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_274.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_274.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_274.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_275.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_275.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_275.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_276.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_276.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_276.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_277.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_277.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_277.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_278.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_278.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_278.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_279.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_279.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_279.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_280.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_280.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_280.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_281.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_281.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_281.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_282.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_282.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_282.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_283.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_283.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_283.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_284.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_284.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_284.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_285.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_285.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_285.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_286.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_286.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_286.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_287.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_287.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_287.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_288.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_288.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_288.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_289.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_289.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_289.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_290.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_290.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_290.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_291.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_291.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_291.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_292.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_292.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_292.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_293.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_293.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_293.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_294.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_294.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_294.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_295.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_295.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_295.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_296.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_296.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_296.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_297.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_297.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_297.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_298.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_298.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_298.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_299.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_299.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_299.jpg' not found. Skipping...
# -----------------------------
# rolled-in_scale_300.jpg
# D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_300.jpg
# Image file 'D:/Downloads/NEU-DET/validation/images/rolled-in\rolled-in_scale_300.jpg' not found. Skipping...
# -----------------------------
# scratches_241.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_241.jpg
# -----------------------------
# scratches_242.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_242.jpg
# -----------------------------
# scratches_243.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_243.jpg
# -----------------------------
# scratches_244.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_244.jpg
# -----------------------------
# scratches_245.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_245.jpg
# -----------------------------
# scratches_246.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_246.jpg
# -----------------------------
# scratches_247.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_247.jpg
# -----------------------------
# scratches_248.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_248.jpg
# -----------------------------
# scratches_249.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_249.jpg
# -----------------------------
# scratches_250.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_250.jpg
# -----------------------------
# scratches_251.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_251.jpg
# -----------------------------
# scratches_252.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_252.jpg
# -----------------------------
# scratches_253.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_253.jpg
# -----------------------------
# scratches_254.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_254.jpg
# -----------------------------
# scratches_255.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_255.jpg
# -----------------------------
# scratches_256.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_256.jpg
# -----------------------------
# scratches_257.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_257.jpg
# -----------------------------
# scratches_258.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_258.jpg
# -----------------------------
# scratches_259.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_259.jpg
# -----------------------------
# scratches_260.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_260.jpg
# -----------------------------
# scratches_261.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_261.jpg
# -----------------------------
# scratches_262.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_262.jpg
# -----------------------------
# scratches_263.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_263.jpg
# -----------------------------
# scratches_264.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_264.jpg
# -----------------------------
# scratches_265.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_265.jpg
# -----------------------------
# scratches_266.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_266.jpg
# -----------------------------
# scratches_267.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_267.jpg
# -----------------------------
# scratches_268.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_268.jpg
# -----------------------------
# scratches_269.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_269.jpg
# -----------------------------
# scratches_270.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_270.jpg
# -----------------------------
# scratches_271.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_271.jpg
# -----------------------------
# scratches_272.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_272.jpg
# -----------------------------
# scratches_273.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_273.jpg
# -----------------------------
# scratches_274.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_274.jpg
# -----------------------------
# scratches_275.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_275.jpg
# -----------------------------
# scratches_276.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_276.jpg
# -----------------------------
# scratches_277.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_277.jpg
# -----------------------------
# scratches_278.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_278.jpg
# -----------------------------
# scratches_279.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_279.jpg
# -----------------------------
# scratches_280.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_280.jpg
# -----------------------------
# scratches_281.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_281.jpg
# -----------------------------
# scratches_282.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_282.jpg
# -----------------------------
# scratches_283.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_283.jpg
# -----------------------------
# scratches_284.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_284.jpg
# -----------------------------
# scratches_285.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_285.jpg
# -----------------------------
# scratches_286.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_286.jpg
# -----------------------------
# scratches_287.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_287.jpg
# -----------------------------
# scratches_288.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_288.jpg
# -----------------------------
# scratches_289.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_289.jpg
# -----------------------------
# scratches_290.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_290.jpg
# -----------------------------
# scratches_291.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_291.jpg
# -----------------------------
# scratches_292.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_292.jpg
# -----------------------------
# scratches_293.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_293.jpg
# -----------------------------
# scratches_294.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_294.jpg
# -----------------------------
# scratches_295.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_295.jpg
# -----------------------------
# scratches_296.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_296.jpg
# -----------------------------
# scratches_297.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_297.jpg
# -----------------------------
# scratches_298.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_298.jpg
# -----------------------------
# scratches_299.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_299.jpg
# -----------------------------
# scratches_300.jpg
# D:/Downloads/NEU-DET/validation/images/scratches\scratches_300.jpg

# %% [markdown]
# ### Task 2: Classification

# %%
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# Load TFRecord datasets
train_tfrecord_path = 'D:/Downloads/NEU-DET/train/output.tfrecord'
val_tfrecord_path = 'D:/Downloads/NEU-DET/validation/output.tfrecord'

# Function to parse TFRecord dataset and extract image dimensions
def extract_input_shape(tfrecord_path):
    max_height = 0
    max_width = 0

    # Define feature description for parsing TFRecord
    feature_description = {
        'image/height': tf.io.FixedLenFeature([], tf.int64),
        'image/width': tf.io.FixedLenFeature([], tf.int64),
    }

    # Create TFRecord dataset
    dataset = tf.data.TFRecordDataset(tfrecord_path)

    # Parse TFRecord examples and extract image dimensions
    for example in dataset:
        parsed_example = tf.io.parse_single_example(example, feature_description)
        height = parsed_example['image/height']
        width = parsed_example['image/width']
        max_height = max(max_height, height)
        max_width = max(max_width, width)

    return max_height, max_width

# Extract input shape from TFRecord dataset
image_height, image_width = extract_input_shape(train_tfrecord_path)
n_color_channels = 3  # As images are not in RGB format

# Load pre-trained Xception base model
base_model = tf.keras.applications.Xception(input_shape=(image_height, image_width, n_color_channels),
                                            include_top=False,
                                            weights="imagenet")

n_classes = 6  # Defining the number of classes in the dataset

batch_size = 32
epochs = 5

# Define preprocessing function for TFRecord datasets
def preprocess_dataset(dataset):
    # Define the feature description for parsing TFRecord
    feature_description = {
        'image/encodedrawdata': tf.io.FixedLenFeature([], tf.string),
        'image/object/class/label': tf.io.FixedLenFeature([], tf.int64),
    }

    # Parse TFRecord examples and preprocess the data
    def _parse_function(example_proto):
        parsed_example = tf.io.parse_single_example(example_proto, feature_description)
        image = tf.image.decode_jpeg(parsed_example['image/encodedrawdata'], channels=3)
        image = tf.image.resize(image, [image_height, image_width])
        image = tf.cast(image, tf.float32) / 255.0  # Normalize pixel values to [0, 1]
        label = tf.cast(parsed_example['image/object/class/label'], tf.int32)
        return image, label

    dataset = dataset.map(_parse_function)
    dataset = dataset.batch(batch_size)  # Batch the dataset
    return dataset


# Extending the base model with additional layers as per the task instructions
x = base_model.output
x = BatchNormalization()(x)
x = GlobalAveragePooling2D()(x)
x = Dense(8, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(n_classes, activation='softmax')(x)

# Create the classification model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(), 
              loss=SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
train_dataset = tf.data.TFRecordDataset(train_tfrecord_path)
val_dataset = tf.data.TFRecordDataset(val_tfrecord_path)

train_dataset = preprocess_dataset(train_dataset)
val_dataset = preprocess_dataset(val_dataset)

history = model.fit(train_dataset, 
                    epochs=epochs, 
                    validation_data=val_dataset,
                    batch_size=batch_size)

# Evaluate the model
loss, accuracy = model.evaluate(val_dataset)
print(f'Validation Loss: {loss}, Validation Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# C:\Users\ratha\anaconda3\lib\site-packages\keras\backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 30/30 [==============================] - 148s 5s/step - loss: 1.6313 - accuracy: 0.3024 - val_loss: 1.7430 - val_accuracy: 0.7667
# Epoch 2/5
# 30/30 [==============================] - 137s 5s/step - loss: 1.2303 - accuracy: 0.6621 - val_loss: 1.6093 - val_accuracy: 0.9958
# Epoch 3/5
# 30/30 [==============================] - 150s 5s/step - loss: 1.0186 - accuracy: 0.7748 - val_loss: 6.3449 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 30/30 [==============================] - 145s 5s/step - loss: 0.8212 - accuracy: 0.7935 - val_loss: 1.8957 - val_accuracy: 0.5500
# Epoch 5/5
# 30/30 [==============================] - 142s 5s/step - loss: 0.6462 - accuracy: 0.7570 - val_loss: 1.3905 - val_accuracy: 0.7667
# 8/8 [==============================] - 6s 779ms/step - loss: 1.3905 - accuracy: 0.7667
# Validation Loss: 1.3904621601104736, Validation Accuracy: 0.7666666507720947
